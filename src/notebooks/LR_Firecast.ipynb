# %%
# !pip install geopandas shapely pyproj fiona
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 77.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import geopandas as gpd

shp_path = '/gdrive/MyDrive/colab/firecast/FRT000102_42/TB_FFAS_FF_OCCRR_42.shp'
gdf = gpd.read_file(shp_path)

print('rows, cols:', gdf.shape)
print('CRS:', gdf.crs)
print('bounds:', gdf.total_bounds)
print('columns:', list(gdf.columns))
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# /tmp/ipython-input-3569227966.py in <cell line: 0>()
#       2
#       3 shp_path = '/gdrive/MyDrive/colab/firecast/FRT000102_42/TB_FFAS_FF_OCCRR_42.shp'
# ----> 4 gdf = gpd.read_file(shp_path)
#       5
#       6 print('rows, cols:', gdf.shape)
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     314
#     315     if engine == "pyogrio":
# --> 316         return _read_file_pyogrio(
#     317             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318         )
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     574         kwargs["columns"] = kwargs.pop("include_fields")
#     575
# ...

# %%
# SGNG_NM이 '강릉시'인 행만 추출
gangneung = gdf[gdf['SGNG_NM'] == '강릉시']

print('rows:', len(gangneung))
# gangneung.head()
# 데이터보니까 2020, 2021년의 자료만 엄청 많음. 2013년 자료는 2개 있어서 없애버릴 예정


from IPython.display import display
display(gangneung)
